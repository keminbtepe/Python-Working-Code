# %%
def toplama(numara1, numara2):
    return numara1 + numara2

# %%
x = int(input("ilk no giriniz"))
y = int(input("ikinci no giriniz"))
toplama(x,y)
# Out:
# ilk no giriniz 10
# ikinci no giriniz 5
# 15

# %% [markdown]
# ## TRY & EXCEPT & ELSE & FİNALLY

# %%
while True:
    try:
        benimInt = int(input("ilk no giriniz"))
    except:
        print("Lütfen geçerli bir no giriniz")
        continue
    else:
        print("tesekkürler")
        break
    finally:
        print("finnaly çagırıldı")
# Out:
# ilk no giriniz atıl
# Lütfen geçerli bir no giriniz
# finnaly çagırıldı
# ilk no giriniz 5
# tesekkürler
# finnaly çagırıldı

# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
