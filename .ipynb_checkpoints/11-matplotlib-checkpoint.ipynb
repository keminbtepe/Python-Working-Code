# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline #plt show yazmamıza gerek olmaz simdilik

# %%
yasListesi = [10,20,30,40,50,60,70,75,80,100]

# %%
kiloListesi = [20,60,80,85,86,87,70,90,95,90]

# %%
numpyYas = np.array(yasListesi)
numpyKilo = np.array(kiloListesi)

# %%
numpyYas
# Out:
# array([ 10,  20,  30,  40,  50,  60,  70,  75,  80, 100])

# %%
numpyKilo
# Out:
# array([20, 60, 80, 85, 86, 87, 70, 90, 95, 90])

# %%
plt.plot(numpyYas,numpyKilo,"r")  # 1. x ekseni 2. y ekseni   R = RED renk kodları
plt.xlabel("Yas")
plt.ylabel("Kilo")
plt.title("Kilonun Yaşa Göre Değişim Grafiği")
#plt.show()
# Out:
# Text(0.5, 1.0, 'Kilonun Yaşa Göre Değişim Grafiği')

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 3  # üzeri 3

# %%
plt.plot(numpyDizisi1,numpyDizisi2,"g*-")  #  * - her veriyi yıldız ile gösterir ///// -- böyle yaparsak kesikli çizgi yapar

# %%
plt.subplot(1,2,1) #subplot alt grafik gibi
plt.plot(numpyDizisi1,numpyDizisi2,"r*-")
plt.subplot(1,2,2) #1 sıra olacak 2 kolon olacak şuan 2.grafigi çiziyorum
plt.plot(numpyDizisi2,numpyDizisi1,"g--")

# %%
benimFigure = plt.figure()  #grafigin en kenar karesel şekli gibi düşünebiliriz
figureAxes = benimFigure.add_axes([0.2,0.2,0.4,0.4]) #0.2 sol taraf eksenin baslangıç 0.2 alt taraftaki eksenin baslangıç noktası
figureAxes.plot(numpyDizisi1,numpyDizisi2,"g")
figureAxes.set_xlabel("X ekseni veri ismi")
figureAxes.set_ylabel("Y ekseni veri ismi")
figureAxes.set_title("Grafik Başlıgı")
#shift tab yaparsak detaylı komut bilgisini verir
# Out:
# Text(0.5, 1.0, 'Grafik Başlıgı')

# %%
figure1 = plt.figure()

eksen1 = figure1.add_axes([0.1,0.1,0.7,0.7])
eksen2 = figure1.add_axes([0.24,0.5,0.2,0.2])

eksen1.plot(numpyDizisi1,numpyDizisi2,"g*-")
eksen1.set_xlabel("X ekseni eksen1")
eksen1.set_ylabel("y ekseni eksen1")
eksen1.set_title("eksen1 Baslık")

eksen2.plot(numpyDizisi2,numpyDizisi1,"r*-")
eksen2.set_xlabel("X ekseni eksen2")
eksen2.set_ylabel("y ekseni eksen2")
eksen2.set_title("Küçük grafik")  # row sıra # cols kolon
# Out:
# Text(0.5, 1.0, 'Küçük grafik')

# %%
(benimFigure, benimEksenler) = plt.subplots(nrows=1,ncols=2)
type(benimEksenler)

for eksen in benimEksenler:
    eksen.plot(numpyDizisi1,numpyDizisi2,"g")
    eksen.set_xlabel("x ekseni")
plt.tight_layout()

# %%
yeniFigure = plt.figure()
# figure için dpi=300 dersek daha kaliteli olur

yeniEksen = yeniFigure.add_axes([0.1,0.1,0.9,0.9])

yeniEksen.plot(numpyDizisi1,numpyDizisi1**2,label = "numpyDizisi karesi ")
yeniEksen.plot(numpyDizisi1,numpyDizisi1**3,label = "numpyDizisi küpü ")
yeniEksen.legend(loc=9)

# %%
yeniFigure.savefig("yeniFigur.png",dpi=400)
