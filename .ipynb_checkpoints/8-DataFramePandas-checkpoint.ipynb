# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 2.03767834, -0.64064509,  1.6427573 ],
#        [-0.12600917, -1.46907809,  0.08375699],
#        [-0.30221697, -0.0599816 ,  0.69849685],
#        [ 0.57059167, -0.24347564,  0.01472088]])

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame  #colmn sütun #row satır
# Out:
#           0         1         2
# 0  2.037678 -0.640645  1.642757
# 1 -0.126009 -1.469078  0.083757
# 2 -0.302217 -0.059982  0.698497
# 3  0.570592 -0.243476  0.014721

# %%
dataFrame[0]
# Out:
# 0    2.037678
# 1   -0.126009
# 2   -0.302217
# 3    0.570592
# Name: 0, dtype: float64

# %%
yeniDataFrame = pd.DataFrame(data,index=["Kürşat","Zeynep","Atlas","Mehmet"],columns=["Maas","Yas","Calisma Saati"])

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kürşat  2.037678 -0.640645       1.642757
# Zeynep -0.126009 -1.469078       0.083757
# Atlas  -0.302217 -0.059982       0.698497
# Mehmet  0.570592 -0.243476       0.014721

# %%
yeniDataFrame[["Maas","Yas"]]
# Out:
#             Maas       Yas
# Kürşat  2.037678 -0.640645
# Zeynep -0.126009 -1.469078
# Atlas  -0.302217 -0.059982
# Mehmet  0.570592 -0.243476

# %%
yeniDataFrame.loc["Kürşat"]
# Out:
# Maas             2.037678
# Yas             -0.640645
# Calisma Saati    1.642757
# Name: Kürşat, dtype: float64

# %%
yeniDataFrame.iloc[0]   # index loc olarak getirir
# Out:
# Maas             2.037678
# Yas             -0.640645
# Calisma Saati    1.642757
# Name: Kürşat, dtype: float64

# %%
yeniDataFrame["Emeklilik Yasi"] = yeniDataFrame["Yas"] * 0.150

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Kürşat  2.037678 -0.640645       1.642757       -0.096097
# Zeynep -0.126009 -1.469078       0.083757       -0.220362
# Atlas  -0.302217 -0.059982       0.698497       -0.008997
# Mehmet  0.570592 -0.243476       0.014721       -0.036521

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis=1)  #axis 1 dedigimiz maas yas alanlarının bulundugu yer ,axis = 0 row olur isimlerin yazıldıgı yer silinir
# Out:
#             Maas       Yas  Calisma Saati
# Kürşat  2.037678 -0.640645       1.642757
# Zeynep -0.126009 -1.469078       0.083757
# Atlas  -0.302217 -0.059982       0.698497
# Mehmet  0.570592 -0.243476       0.014721

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis=1 , inplace=True)  #inplace kalıcı olarak silmemizi saglar

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kürşat  2.037678 -0.640645       1.642757
# Zeynep -0.126009 -1.469078       0.083757
# Atlas  -0.302217 -0.059982       0.698497
# Mehmet  0.570592 -0.243476       0.014721

# %%
yeniDataFrame.loc["Kürşat"]["Calisma Saati"]
# Out:
# np.float64(1.6427572985011618)

# %%
yeniDataFrame.loc["Kürşat","Yas"]
# Out:
# np.float64(-0.6406450855723206)

# %%
yeniDataFrame < 0
# Out:
#          Maas   Yas  Calisma Saati
# Kürşat  False  True          False
# Zeynep   True  True          False
# Atlas    True  True          False
# Mehmet  False  True          False

# %%
yeniDataFrame[yeniDataFrame>0]   #sıfırdan küçükleri boş gösterir
# Out:
#             Maas  Yas  Calisma Saati
# Kürşat  2.037678  NaN       1.642757
# Zeynep       NaN  NaN       0.083757
# Atlas        NaN  NaN       0.698497
# Mehmet  0.570592  NaN       0.014721

# %%
yeniDataFrame["Maas"] > 0
# Out:
# Kürşat     True
# Zeynep    False
# Atlas     False
# Mehmet     True
# Name: Maas, dtype: bool

# %%
yeniDataFrame[yeniDataFrame["Maas"]>0]  #maası sıfırdan büyük olanları getirir
# Out:
#             Maas       Yas  Calisma Saati
# Kürşat  2.037678 -0.640645       1.642757
# Mehmet  0.570592 -0.243476       0.014721

# %%
yeniDataFrame.reset_index()  # baş tarafa numaralandırma yapar inplace kullanırsak kalıcı olur
# Out:
#     index      Maas       Yas  Calisma Saati
# 0  Kürşat  2.037678 -0.640645       1.642757
# 1  Zeynep -0.126009 -1.469078       0.083757
# 2   Atlas -0.302217 -0.059982       0.698497
# 3  Mehmet  0.570592 -0.243476       0.014721

# %%
yeniİsimler = ["Kur","Zey","Atl","Meh"]

# %%
yeniDataFrame["Yeni Indeks"] = yeniİsimler

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati Yeni Indeks
# Kürşat  2.037678 -0.640645       1.642757         Kur
# Zeynep -0.126009 -1.469078       0.083757         Zey
# Atlas  -0.302217 -0.059982       0.698497         Atl
# Mehmet  0.570592 -0.243476       0.014721         Meh

# %%
yeniDataFrame.set_index("Yeni Indeks") #inplace yapmadıgımız için kalıcı olmaz
# Out:
#                  Maas       Yas  Calisma Saati
# Yeni Indeks
# Kur          2.037678 -0.640645       1.642757
# Zey         -0.126009 -1.469078       0.083757
# Atl         -0.302217 -0.059982       0.698497
# Meh          0.570592 -0.243476       0.014721

# %%
yeniDataFrame.set_index("Yeni Indeks",inplace=True)

# %%
yeniDataFrame
# Out:
#                  Maas       Yas  Calisma Saati
# Yeni Indeks
# Kur          2.037678 -0.640645       1.642757
# Zey         -0.126009 -1.469078       0.083757
# Atl         -0.302217 -0.059982       0.698497
# Meh          0.570592 -0.243476       0.014721

# %%
yeniDataFrame["Maas"]
# Out:
# Yeni Indeks
# Kur    2.037678
# Zey   -0.126009
# Atl   -0.302217
# Meh    0.570592
# Name: Maas, dtype: float64

# %%
yeniDataFrame.loc["Kur"]
# Out:
# Maas             2.037678
# Yas             -0.640645
# Calisma Saati    1.642757
# Name: Kur, dtype: float64

# %%
yeniDataFrame.iloc[1]
# Out:
# Maas            -0.126009
# Yas             -1.469078
# Calisma Saati    0.083757
# Name: Zey, dtype: float64

# %%
ilkIndex = ["yasli","yasli","yasli","genc","genc","genc"]

# %%
icIndex = ["ahmet","kursat","kader","zeliha","zeynep","ali"]

# %%
birlesmisIndex = list(zip(ilkIndex,icIndex))

# %%
birlesmisIndex
# Out:
# [('yasli', 'ahmet'),
#  ('yasli', 'kursat'),
#  ('yasli', 'kader'),
#  ('genc', 'zeliha'),
#  ('genc', 'zeynep'),
#  ('genc', 'ali')]

# %%
birlesmisIndex = pd.MultiIndex.from_tuples(birlesmisIndex)

# %%
birlesmisIndex
# Out:
# MultiIndex([('yasli',  'ahmet'),
#             ('yasli', 'kursat'),
#             ('yasli',  'kader'),
#             ( 'genc', 'zeliha'),
#             ( 'genc', 'zeynep'),
#             ( 'genc',    'ali')],
#            )

# %%
type(birlesmisIndex)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
benimData = [[155,65],[175,75],[185,34],[165,45],[156,55],[167,42]]

# %%
numpyDizim = np.array(benimData)

# %%
numpyDizim
# Out:
# array([[155,  65],
#        [175,  75],
#        [185,  34],
#        [165,  45],
#        [156,  55],
#        [167,  42]])

# %%
boykiloDataFrame = pd.DataFrame(numpyDizim, index=birlesmisIndex,columns=["boy","kilo"])

# %%
boykiloDataFrame
# Out:
#               boy  kilo
# yasli ahmet   155    65
#       kursat  175    75
#       kader   185    34
# genc  zeliha  165    45
#       zeynep  156    55
#       ali     167    42

# %%
boykiloDataFrame.loc["yasli"]
# Out:
#         boy  kilo
# ahmet   155    65
# kursat  175    75
# kader   185    34

# %%
boykiloDataFrame.loc["genc"].loc["zeliha"]
# Out:
# boy     165
# kilo     45
# Name: zeliha, dtype: int64

# %%
boykiloDataFrame.index.names = ["Durum","İsim"]

# %%
boykiloDataFrame
# Out:
#               boy  kilo
# Durum İsim
# yasli ahmet   155    65
#       kursat  175    75
#       kader   185    34
# genc  zeliha  165    45
#       zeynep  156    55
#       ali     167    42
