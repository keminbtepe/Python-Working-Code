# %%
name = "kursat besiktepe"

# %%
name[0]
# Out:
# 'k'

# %%
name.upper()
# Out:
# 'KURSAT BESIKTEPE'

# %%
len(name)
# Out:
# 16

# %%
name[len(name) - 1]
# Out:
# 'e'

# %%
name[0:8:2]  # 0 dan basla sondan 8e kadar 2 şer atlayarak git
# Out:
# 'kra '

# %%
name[0:15]
# Out:
# 'kursat besiktep'

# %%
name[::-1]
# Out:
# 'epetkiseb tasruk'

# %%
name[-4:]
# Out:
# 'tepe'

# %%
name.index("a")
# Out:
# 4

# %%
name[4:]
# Out:
# 'at besiktepe'

# %%
name.split() # liste olarak ayrı ayrı yazar
# Out:
# ['kursat', 'besiktepe']

# %% [markdown]
# ## LİST

# %%
myList = [10,20,30,40,50,60,70]

# %%
myList.reverse()

# %%
myList
# Out:
# [70, 60, 50, 40, 30, 20, 10]

# %%
myList.append(5)  #en sona ekleme yapar
myList
# Out:
# [70, 60, 50, 40, 30, 20, 10, 5]

# %%
myList.insert(3,55)  #istedigimiz indexe ekleme yapar

# %%
myList
# Out:
# [70, 60, 50, 55, 40, 30, 20, 10, 5]

# %%
namee = input("adınızı giriniz:")
surname = input("soyadınızı giriniz:")
age = input("yaşınızı giriniz:")
# Out:
# adınızı giriniz: kürşat
# soyadınızı giriniz: beşiktepe
# yaşınızı giriniz: 25

# %%
int(age) *2
# Out:
# 50

# %%
str(int(age))  #inti stringe çevirdik
# Out:
# '25'

# %%
lastList = ["a","b","c",["d","e","f"],"e"]
lastList[3][0]   #3. elemanın 0.elemanını alır
# Out:
# 'd'

# %% [markdown]
# ## Sözlük Dict

# %%
# listeden farkı index mantıgı yerine biizm belirledigimiz şeyi yazıp çagırırız

# %%
fitnessInfo = {"banana":100,"tomato":200}

# %%
fitnessInfo["banana"]
# Out:
# 100

# %%
fitnessInfo.keys()
# Out:
# dict_keys(['banana', 'tomato'])

# %%
fitnessInfo.values()
# Out:
# dict_values([100, 200])

# %%
list(fitnessInfo.keys())
# Out:
# ['banana', 'tomato']

# %%
fitnessInfo["banana"] = 350

# %%
fitnessInfo["banana"]
# Out:
# 350

# %%
fitnessInfo.get("banan",0)  # yanlıs yazınca 0 degerini verir hata vermez
# Out:
# 0

# %%
myMixTuple = {"key1":10,"key2":3.16,"key3":[10,20,30],"key4":{"a":10,"b":50,"c":30}}

# %%
myMixTuple
# Out:
# {'key1': 10,
#  'key2': 3.16,
#  'key3': [10, 20, 30],
#  'key4': {'a': 10, 'b': 50, 'c': 30}}

# %%
myMixTuple["key3"][1]
# Out:
# 20

# %%
myMixTuple["key4"]["b"]
# Out:
# 50

# %%
myList = [10,20,30,40]

# %%
myDict = {10,20,30,40}

# %%
mySet = set(myList)
mySet1 = set(myTuple)
# Out:
# {10, 20, 30, 40}

# %%
mySet1
# Out:
# {10, 20, 30, 40}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet1.add(30)  #setler eşsizdir aynı seyleri eklesende bi sey fark etmez

# %%
mySet1
# Out:
# {10, 20, 30, 40}

# %%
mySet1.add(50)

# %%
mySet1
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2 = 30,40,50,60

# %%
mySet1.union(mySet2)
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
emptyList = list()  #boş olusturma

# %%
emptyList.append(10)
emptyList.append(40)
emptyList.append(50)
emptyList.append(60)
emptyList
# Out:
# [10, 40, 50, 60]

# %%
emptySet = set()

# %%
emptyDict = dict()

# %%
emptyDict["a"] = 10
emptyDict["b"] = 20
emptyDict["c"] = 30

# %%
emptyDict
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %% [markdown]
# ## TUPLE

# %%
myTuple = (10,"saglık",3.15,"bar",10)  #degistirilemez güncellenemez eklenemez genelde kütüphaneler kullanır

# %%
myTuple.index("saglık")
# Out:
# 1

# %%
myTuple.count(10)
# Out:
# 2

# %%
myBoolean = True

# %%
5>2
# Out:
# True

# %%
userAge = input("yasinizi giriniz:")
int(userAge) > 18
# Out:
# yasinizi giriniz: 50
# True
